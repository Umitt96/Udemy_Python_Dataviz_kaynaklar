# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %% [markdown]
# ## Veri seti

# %%
x_veri = np.arange(1,7)

# %%
y_veri = np.array([5,2,6,8,4,3])

# %%
etiketler = ['A','B','C','D','E','F']

# %%
# tekli veri seti
np.random.seed(1)
x_tek_veri = 4 + np.random.normal(0, 1.5, 200)

# %% [markdown]
# ## Line

# %%
plt.plot(x_veri,y_veri)
plt.title("Deneme grafiği", fontsize = 16)
plt.xlabel("X ekseni")
plt.ylabel("Y ekseni")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Bar

# %%
plt.figure(figsize=(6,4))
plt.bar(x_veri,y_veri, color="orange")
plt.title("Bar grafiği örneği", fontsize= 16)
plt.show()

# %% [markdown]
# ## Histogram

# %%
plt.figure(figsize=(6,4))
plt.hist(x, bins=15,edgecolor="black")
plt.title("Histogram örneği", fontsize= 16)
plt.show()

# %% [markdown]
# ## Pie

# %%
plt.figure(figsize=(6,6))
plt.pie(x_veri, labels=etiketler, autopct="%1.1f%%")
plt.title("Pasta grafiği", fontsize= 16)
plt.show()

# %% [markdown]
# ## Boxplot

# %%
plt.figure(figsize=(6,6))
plt.boxplot(y_veri, labels=["Veriler"])
plt.title("Boxplot grafiği", fontsize= 16)
plt.show()
